# %% [markdown]
# # Preposition Sense Disambiguation

# %%
# Imports
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import data
import main
import importlib

# %%
preposition_list = ['about', 'above', 'across', 'after', 'against', 'along', 'among', 'around', 'as', 'at', 'before', 'behind', 'beneath', 'beside', 'between', 'by', 'down', 'during', 'for', 'from', 'in', 'inside', 'into', 'like', 'of', 'off', 'on', 'onto', 'over', 'round', 'through', 'to', 'towards', 'with']

# %%
# choose files [one file per preposition]
preposition = 'for'
train_file = './data_assn1/Train/Source/pp-%s.sents.trng.xml' % preposition
test_file = './data_assn1/Test/Source/pp-%s.sents.test.xml' % preposition
test_file_out = './test_out/%s' % preposition

# %%
# get feature_dict
importlib.reload(data)
train, test = data.gen_train_test(2)
# Out:
# pp-down.sents.trng.xml
# #Sentences in corpus 332
# pp-into.sents.trng.xml
# #Sentences in corpus 604
# pp-around.sents.trng.xml
# #Sentences in corpus 335
# pp-round.sents.trng.xml
# #Sentences in corpus 181
# pp-after.sents.trng.xml
# #Sentences in corpus 103
# pp-of.sents.trng.xml
# #Sentences in corpus 3000
# pp-on.sents.trng.xml
# #Sentences in corpus 872
# pp-inside.sents.trng.xml
# #Sentences in corpus 67
# pp-by.sents.trng.xml
# #Sentences in corpus 509
# pp-from.sents.trng.xml
# #Sentences in corpus 1204
# pp-in.sents.trng.xml
# #Sentences in corpus 1391
# pp-beside.sents.trng.xml
# #Sentences in corpus 62
# pp-onto.sents.trng.xml
# #Sentences in corpus 117
# pp-to.sents.trng.xml
# #Sentences in corpus 1182
# pp-during.sents.trng.xml
# #Sentences in corpus 81
# pp-like.sents.trng.xml
# #Sentences in corpus 266
# pp-beneath.sents.trng.xml
# #Sentences in corpus 57
# pp-as.sents.trng.xml
# #Sentences in corpus 173
# pp-at.sents.trng.xml
# #Sentences in corpus 715
# pp-off.sents.trng.xml
# #Sentences in corpus 161
# pp-for.sents.trng.xml
# #Sentences in corpus 950
# pp-behind.sents.trng.xml
# #Sentences in corpus 138
# pp-against.sents.trng.xml
# #Sentences in corpus 195
# pp-towards.sents.trng.xml
# #Sentences in corpus 214
# pp-above.sents.trng.xml
# #Sentences in corpus 48
# pp-through.sents.trng.xml
# #Sentences in corpus 440
# pp-along.sents.trng.xml
# #Sentences in corpus 364
# pp-over.sents.trng.xml
# #Sentences in corpus 200
# pp-across.sents.trng.xml
# #Sentences in corpus 319
# pp-before.sents.trng.xml
# #Sentences in corpus 47
# pp-between.sents.trng.xml
# #Sentences in corpus 211
# pp-with.sents.trng.xml
# #Sentences in corpus 1187
# pp-among.sents.trng.xml
# #Sentences in corpus 100
# pp-about.sents.trng.xml
# #Sentences in corpus 710
# pp-inside.sents.test.xml
# #Sentences in corpus 38
# pp-by.sents.test.xml
# #Sentences in corpus 248
# pp-from.sents.test.xml
# #Sentences in corpus 578
# pp-in.sents.test.xml
# #Sentences in corpus 688
# pp-beside.sents.test.xml
# #Sentences in corpus 29
# pp-onto.sents.test.xml
# #Sentences in corpus 58
# pp-to.sents.test.xml
# #Sentences in corpus 572
# pp-during.sents.test.xml
# #Sentences in corpus 39
# pp-like.sents.test.xml
# #Sentences in corpus 125
# pp-down.sents.test.xml
# #Sentences in corpus 153
# pp-into.sents.test.xml
# #Sentences in corpus 297
# pp-around.sents.test.xml
# #Sentences in corpus 155
# pp-round.sents.test.xml
# #Sentences in corpus 82
# pp-after.sents.test.xml
# #Sentences in corpus 53
# pp-of.sents.test.xml
# #Sentences in corpus 1478
# pp-on.sents.test.xml
# #Sentences in corpus 441
# pp-above.sents.test.xml
# #Sentences in corpus 23
# pp-through.sents.test.xml
# #Sentences in corpus 208
# pp-across.sents.test.xml
# #Sentences in corpus 151
# pp-along.sents.test.xml
# #Sentences in corpus 173
# pp-over.sents.test.xml
# #Sentences in corpus 98
# pp-before.sents.test.xml
# #Sentences in corpus 20
# pp-between.sents.test.xml
# #Sentences in corpus 102
# pp-with.sents.test.xml
# #Sentences in corpus 578
# pp-among.sents.test.xml
# #Sentences in corpus 50
# pp-about.sents.test.xml
# #Sentences in corpus 364
# pp-beneath.sents.test.xml
# #Sentences in corpus 28
# pp-as.sents.test.xml
# #Sentences in corpus 84
# pp-at.sents.test.xml
# #Sentences in corpus 367
# pp-off.sents.test.xml
# #Sentences in corpus 76
# pp-for.sents.test.xml
# #Sentences in corpus 478
# pp-behind.sents.test.xml
# #Sentences in corpus 68
# pp-against.sents.test.xml
# #Sentences in corpus 92
# pp-towards.sents.test.xml
# #Sentences in corpus 102

# %%
importlib.reload(main)
X_train, X_test, Y_train, train_sentences, test_sentences = main.process_preposition_data(train['about'], test['about'])
print(len(train_sentences))
print(len(test_sentences))
# Out:
# X_train:  (710, 150)
# X_test:  (364, 150)
# Y_train:  (710, 1)
# 710
# 364

# %%
print(train_sentences[:3])
print(test_sentences[:3])
# Out:
# ['he saw owen redden with pleasure , and laughed , flinging an arm about his shoulders so forgetfully that it was a worthy as well as a willing sacrifice owen made for him , containing the pain of the embrace .'
#  '` but i do ! " she exclaimed , almost throwing herself back into his arms , and frenziedly clasping her hands about his neck .'
#  'it would appear that , while there is a growing increase in awareness about the importance of evaluation in library user education programmes , many librarians still do not systematically evaluate their programmes .']
# ['campaigns have been held across a number of universities asking this question to raise awareness about aids and hiv .'
#  'the increase in skin cancer across the globe has led to growing awareness about the damaging effects of sunlight on skin .'
#  'this management process will also require the creation of customer awareness about the product , its price and availability .']

# %%
# test some entries in the dictionary
X=train['for']['sents']
Y=train['for']['labels']
print(X[:3])
# Out:
# [{'vl': array([ 0.47027   , -0.012185  ,  0.017029  , -0.16612001,  0.796405  ,
#         0.377465  , -0.26767498,  0.1719355 , -0.369003  ,  0.1877945 ,
#        -1.133657  , -0.42892998,  0.2794005 , -0.082165  ,  0.647665  ,
#         2.8660998 , -0.78224003, -0.60168004, -0.38520998,  0.52635   ,
#         0.0792595 ,  0.222485  ,  0.437965  , -0.02301501, -0.561265  ,
#         0.06288949, -0.32538497,  0.18665498,  0.42598602, -0.2973775 ,
#        -0.20723999,  0.655485  ,  0.256709  ,  0.737115  ,  0.1319945 ],
#       dtype=float32), 'vr': array([ 3.0884999e-01, -2.1690001e-01, -7.8034002e-01,  2.8417051e-01,
#        -3.0474998e-02,  1.3088500e-01, -4.6113500e-01, -3.5599992e-02,
#         7.9471505e-01,  3.2386500e-01, -1.8559749e-01,  4.7562999e-01,
#         9.8929000e-01, -3.9000064e-03,  4.5877498e-01, -2.0177999e-01,
#         4.1114700e-01,  1.8991500e-01, -4.8010498e-01, -3.7620997e-01,
#         4.6197000e-01, -2.8155002e-01,  8.7607998e-01, -3.2737499e-01,
#        -2.3544352e-01, -7.0264995e-01,  1.3423151e-01, -1.4972301e-01,
#         3.7457502e-01, -8.8382505e-02,  2.2354300e+00,  1.2972000e-01,
#        -2.9000640e-04, -6.1989993e-02,  3.8617000e-01,  4.9009499e-01,
#        -1.9979998e-02,  3.1961000e-01,  4.3305200e-01,  3.3350006e-02,
#        -5.5888051e-01,  1.4725301e-01,  3.9824849e-01,  5.7866502e-01,
#         6.5740496e-01,  2.2042200e-01, -6.2605000e-01,  2.9300004e-02,
#         2.1344151e-01, -2.5465004e-02], dtype=float32), 'vi': array([ 0.05610718,  0.7104262 , -0.8670474 ,  0.25748467,  0.4171406 ,
#         0.86641437, -0.7863752 , -0.8381531 ,  0.3982849 , -0.31846726,
#         0.13009912, -0.16477089, -0.3602708 ,  0.18663907,  0.41783807,
#        -0.5755553 , -0.0234171 ,  0.16777553, -1.1324521 , -0.7594006 ,
#        -0.399406  , -0.2007822 , -0.0657884 , -0.04111059, -0.5741833 ,
#        -2.6339674 , -0.39508882,  0.0767077 , -0.05230395,  0.3582784 ,
#         5.804868  , -0.47380084, -1.0719774 , -0.46381235,  0.67073035,
#         0.24227442,  0.42311344,  0.5437497 ,  0.11504458, -0.8136072 ,
#         0.00634525, -0.06283602, -0.03101116,  0.41881564, -0.35747495,
#        -0.2263464 ,  0.24050495,  0.39205438,  0.61499983,  0.17371036],
#       dtype=float32), 'sentence': 'the dornoch firth is one of the very few areas around the british isles given a grade a classification for shellfish purity .'}]

# %% [markdown]
# ## Split data into Features, Labels

# %%
test_fraction = 0.1

# first x columns correspond to features, 5th column contains the class labels
X = 
Y = dataset.iloc[:, x].values

# The dataset is shuffled with 10 as the random seed for reproducible results.
X_train, X_test, y_train, y_test = train_test_split(X, Y, shuffle=True, random_state=10, test_size=test_fraction)

print("Number of train samples: ", len(X_train))
print("Number of test samples: ", len(X_test))

# %%
# Train classifier
